# %%
# Import libraries

import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns # data visualization
from matplotlib import pyplot as plt
from kaggle_olympic_games_medals import KaggleOlympicGamesMedals

# %%
data = {
    'Category1': [10, 15, 8],
    'Category2': [5, 12, 6],
    'Category3': [7, 9, 11]
}

df = pd.DataFrame(data, index=['A', 'B', 'C'])
df
# Out:
#    Category1  Category2  Category3
# A         10          5          7
# B         15         12          9
# C          8          6         11

# %%
ax = df.plot(kind='bar', stacked=True, color=['peru', 'silver', 'gold'])
plt.title('Stacked Bar Chart using Pandas')
plt.xlabel('X-axis Label')
plt.ylabel('Y-axis Label')
plt.show()

# %%
# https://worldhappiness.report/ed/2024/#appendices-and-data
df = pd.read_excel('../data/world-happiness/DataForTable2.1.xls')
df.head()
df.to_csv('../data/world-happiness/global_happiness.csv', index=False)

# %%
df_happiness = pd.read_csv('../data/world-happiness/global_happiness.csv')
df_happiness.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2363 entries, 0 to 2362
# Data columns (total 11 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Country name                      2363 non-null   object
#  1   year                              2363 non-null   int64
#  2   Life Ladder                       2363 non-null   float64
#  3   Log GDP per capita                2335 non-null   float64
#  4   Social support                    2350 non-null   float64
#  5   Healthy life expectancy at birth  2300 non-null   float64
#  6   Freedom to make life choices      2327 non-null   float64
#  7   Generosity                        2282 non-null   float64
#  8   Perceptions of corruption         2238 non-null   float64
#  9   Positive affect                   2339 non-null   float64
#  10  Negative affect                   2347 non-null   float64
# dtypes: float64(9), int64(1), object(1)
# ...

# %%
df_happiness.describe()
# Out:
#         Unnamed: 0         year  Life Ladder  Log GDP per capita  \
# count  2363.000000  2363.000000  2363.000000         2335.000000
# mean   1181.000000  2014.763860     5.483562            9.399673
# std     682.283665     5.059436     1.125523            1.152062
# min       0.000000  2005.000000     1.281271            5.526723
# 25%     590.500000  2011.000000     4.646750            8.506165
# 50%    1181.000000  2015.000000     5.448725            9.502946
# 75%    1771.500000  2019.000000     6.323592           10.392974
# max    2362.000000  2023.000000     8.018934           11.675588
#
#        Social support  Healthy life expectancy at birth  \
# count     2350.000000                       2300.000000
# mean         0.809369                         63.401828
# std          0.121211                          6.842644
# min          0.228217                          6.720000
# 25%          0.743811                         59.195001
# ...

# %%
df_happiness.head()
# Out:
#    Unnamed: 0 Country name  year  Life Ladder  Log GDP per capita  \
# 0           0  Afghanistan  2008     3.723590            7.350416
# 1           1  Afghanistan  2009     4.401778            7.508646
# 2           2  Afghanistan  2010     4.758381            7.613900
# 3           3  Afghanistan  2011     3.831719            7.581259
# 4           4  Afghanistan  2012     3.782938            7.660506
#
#    Social support  Healthy life expectancy at birth  \
# 0        0.450662                         50.500000
# 1        0.552308                         50.799999
# 2        0.539075                         51.099998
# 3        0.521104                         51.400002
# 4        0.520637                         51.700001
#
#    Freedom to make life choices  Generosity  Perceptions of corruption  \
# 0                      0.718114    0.164055                   0.881686
# 1                      0.678896    0.187297                   0.850035
# ...

# %%
#temp = df.value_counts('Country name').sort_index(ascending=True).nunique()
temp = df['Country name'].unique()
temp
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'Angola', 'Argentina',
#        'Armenia', 'Australia', 'Austria', 'Azerbaijan', 'Bahrain',
#        'Bangladesh', 'Belarus', 'Belgium', 'Belize', 'Benin', 'Bhutan',
#        'Bolivia', 'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'Bulgaria', 'Burkina Faso', 'Burundi', 'Cambodia', 'Cameroon',
#        'Canada', 'Central African Republic', 'Chad', 'Chile', 'China',
#        'Colombia', 'Comoros', 'Congo (Brazzaville)', 'Congo (Kinshasa)',
#        'Costa Rica', 'Croatia', 'Cuba', 'Cyprus', 'Czechia', 'Denmark',
#        'Djibouti', 'Dominican Republic', 'Ecuador', 'Egypt',
#        'El Salvador', 'Estonia', 'Eswatini', 'Ethiopia', 'Finland',
#        'France', 'Gabon', 'Gambia', 'Georgia', 'Germany', 'Ghana',
#        'Greece', 'Guatemala', 'Guinea', 'Guyana', 'Haiti', 'Honduras',
#        'Hong Kong S.A.R. of China', 'Hungary', 'Iceland', 'India',
#        'Indonesia', 'Iran', 'Iraq', 'Ireland', 'Israel', 'Italy',
# ...

# %%
nutrition_cols_ref = {
    'column_name':[
        'country_code',
        'country_name',
        'CoCA_pct',
        'CoNA_pct',
        'CoHD_pct',
        'CoCA_mills',
        'CoNA_mills',
        'CoHD_mills',
        'Pop'
    ],
    'column_description': [
        'Country Code',
        'Country Name',
        'Percent of the population who cannot afford sufficient calories [CoCA_headcount]',
        'Percent of the population who cannot afford nutrient adequacy [CoNA_headcount]',
        'Percent of the population who cannot afford a healthy diet [CoHD_headcount]',
        'Millions of people who cannot afford sufficient calories [CoCA_unafford_n]',
        'Millions of people who cannot afford nutrient adequacy [CoNA_unafford_n]',
        'Millions of people who cannot afford a healthy life [CoHD_unafford_n]',
        'Population [Pop]'
    ],
}
df = pd.DataFrame(nutrition_cols_ref, index=range(0, len(nutrition_cols_ref['column_name'])))
df
# Out:
#     column_name                                 column_description
# 0  country_code                                       Country Code
# 1  country_name                                       Country Name
# 2      CoCA_pct  Percent of the population who cannot afford su...
# 3      CoNA_pct  Percent of the population who cannot afford nu...
# 4      CoHD_pct  Percent of the population who cannot afford a ...
# 5    CoCA_mills  Millions of people who cannot afford sufficien...
# 6    CoNA_mills  Millions of people who cannot afford nutrient ...
# 7    CoHD_mills  Millions of people who cannot afford a healthy...
# 8           Pop                                   Population [Pop]

# %%
from sklearn.preprocessing import MinMaxScaler

# Create a sample DataFrame
data = {
    'Age': [10, 35, 34, 23, 70, 55, 89],
    'Height': [130, 178, 155, 133, 195, 150, 205],
    'Weight': [80, 200, 220, 150, 140, 95, 180]
}
df = pd.DataFrame(data)

# Initialize the MinMaxScaler
scaler = MinMaxScaler()

# Normalize the numeric columns
df[['Age', 'Height', 'Weight']] = scaler.fit_transform(df[['Age', 'Height', 'Weight']])

df
# Out:
#         Age    Height    Weight
# 0  0.000000  0.000000  0.000000
# 1  0.316456  0.640000  0.857143
# 2  0.303797  0.333333  1.000000
# 3  0.164557  0.040000  0.500000
# 4  0.759494  0.866667  0.428571
# 5  0.569620  0.266667  0.107143
# 6  1.000000  1.000000  0.714286

# %%
df_medals = pd.read_csv('../data/kaggle/olympic-games-medals/olympic_medals.csv')
df_medals
# Out:
#       discipline_title     slug_game                      event_title  \
# 0              Curling  beijing-2022                    Mixed Doubles
# 1              Curling  beijing-2022                    Mixed Doubles
# 2              Curling  beijing-2022                    Mixed Doubles
# 3              Curling  beijing-2022                    Mixed Doubles
# 4              Curling  beijing-2022                    Mixed Doubles
# ...                ...           ...                              ...
# 21692    Weightlifting   athens-1896  heavyweight - one hand lift men
# 21693    Weightlifting   athens-1896  heavyweight - one hand lift men
# 21694    Weightlifting   athens-1896  heavyweight - two hand lift men
# 21695    Weightlifting   athens-1896  heavyweight - two hand lift men
# 21696    Weightlifting   athens-1896  heavyweight - two hand lift men
#
#       event_gender medal_type participant_type participant_title  \
# ...

# %%
df_nutrition = pd.read_csv('../data/World_Bank/Food_Prices_for_Nutrition.csv', encoding = "ISO-8859-1")
df_nutrition
# Out:
#                                 Classification Name Classification Code  \
# 0                     Food Prices for Nutrition 1.0             FPN 1.0
# 1                     Food Prices for Nutrition 1.0             FPN 1.0
# 2                     Food Prices for Nutrition 1.0             FPN 1.0
# 3                     Food Prices for Nutrition 1.0             FPN 1.0
# 4                     Food Prices for Nutrition 1.0             FPN 1.0
# ...                                             ...                 ...
# 3720                                            NaN                 NaN
# 3721                                            NaN                 NaN
# 3722                                            NaN                 NaN
# 3723  Data from database: Food Prices for Nutrition                 NaN
# 3724                       Last Updated: 12/15/2023                 NaN
#
#      Country Name Country Code    Time Time Code  \
# 0         Albania          ALB  2017.0    YR2017
# ...

# %%
df_happiness = pd.read_csv('../data/world-happiness/world_happiness.csv')
df_happiness
# Out:
#      Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 0     Afghanistan  2008     3.723590            7.350416        0.450662
# 1     Afghanistan  2009     4.401778            7.508646        0.552308
# 2     Afghanistan  2010     4.758381            7.613900        0.539075
# 3     Afghanistan  2011     3.831719            7.581259        0.521104
# 4     Afghanistan  2012     3.782938            7.660506        0.520637
# ...           ...   ...          ...                 ...             ...
# 2358     Zimbabwe  2019     2.693523            7.697755        0.759162
# 2359     Zimbabwe  2020     3.159802            7.596050        0.717243
# 2360     Zimbabwe  2021     3.154578            7.656878        0.685151
# 2361     Zimbabwe  2022     3.296220            7.670073        0.666172
# 2362     Zimbabwe  2023     3.572386            7.678590        0.693817
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# ...

# %%
df_gdp = pd.read_csv('../data/World_Bank/GDP_1960_2023.csv', encoding = "ISO-8859-1")
df_gdp
# Out:
#                     Country Name Country Code          1960          1961  \
# 0                          Aruba          ABW           NaN           NaN
# 1    Africa Eastern and Southern          AFE  2.121696e+10  2.230747e+10
# 2                    Afghanistan          AFG           NaN           NaN
# 3     Africa Western and Central          AFW  1.188413e+10  1.268566e+10
# 4                         Angola          AGO           NaN           NaN
# ..                           ...          ...           ...           ...
# 261                       Kosovo          XKX           NaN           NaN
# 262                  Yemen, Rep.          YEM           NaN           NaN
# 263                 South Africa          ZAF  8.748597e+09  9.225996e+09
# 264                       Zambia          ZMB  7.130000e+08  6.962857e+08
# 265                     Zimbabwe          ZWE  1.052990e+09  1.096647e+09
#
#              1962          1963          1964          1965          1966  \
# ...
